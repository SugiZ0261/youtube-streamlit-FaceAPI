# %%
import requests
from PIL import Image

# %%
subscription_key = '7ab73decb4dc4191a59fb23b021ebf8b'

# %%
assert subscription_key

# %%
face_api_url = 'https://20211125sugizaki.cognitiveservices.azure.com/face/v1.0/detect'

# %%
img = Image.open('sample1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x473 at 0x7FC80D04F590>

# %%
with open('sample1.jpg', 'rb') as f:
    binary_img = f.read() # 画像をバイナリデータで読み込む

# %%
# binary_img

# %%
headers = {
    'Content-Type': 'application/octet-stream',
    'Ocp-Apim-Subscription-Key': subscription_key
}

params = {
    'returnFaceId': 'true',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise'
}

res = requests.post(face_api_url, params=params, headers=headers, data=binary_img)

# %%
res # 200が返ってきていれば成功
# Out:
# <Response [200]>

# %%
result = res.json()
result
# Out:
# [{'faceId': '1eb018b0-0353-4423-8b55-6dc096241b95',
#   'faceRectangle': {'top': 136, 'left': 220, 'width': 189, 'height': 189},
#   'faceAttributes': {'smile': 1.0,
#    'headPose': {'pitch': 0.6, 'roll': -0.8, 'yaw': 9.5},
#    'gender': 'male',
#    'age': 37.0,
#    'facialHair': {'moustache': 0.1, 'beard': 0.1, 'sideburns': 0.1},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'low', 'value': 0.13},
#    'exposure': {'exposureLevel': 'goodExposure', 'value': 0.67},
#    'noise': {'noiseLevel': 'low', 'value': 0.0},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': False},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.07,
#     'invisible': False,
# ...

# %%
rect = result[0]['faceRectangle']
rect
# Out:
# {'top': 136, 'left': 220, 'width': 189, 'height': 189}

# %%
from PIL import ImageDraw

# %%
draw = ImageDraw.Draw(img) # imgに描画の準備をする

# %%
# draw.line([(0,50), (200,50), (0,150), (200,150)], fill='red', width=5)
# img

# %%
rect
# Out:
# {'top': 136, 'left': 220, 'width': 189, 'height': 189}

# %%
draw.rectangle([(rect['left'], rect['top']), (rect['left']+rect['width'], rect['top']+rect['height'])], fill=None, outline='green', width=5)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x473 at 0x7FB569C02AD0>

# %%
import requests
from PIL import Image
from PIL import ImageDraw
    
subscription_key = '7ab73decb4dc4191a59fb23b021ebf8b'
assert subscription_key

face_api_url = 'https://20211125sugizaki.cognitiveservices.azure.com/face/v1.0/detect'

img = Image.open('sample2.jpg')
with open('sample2.jpg', 'rb') as f:
    binary_img = f.read() # 画像をバイナリデータで読み込む
    
headers = {
    'Content-Type': 'application/octet-stream',
    'Ocp-Apim-Subscription-Key': subscription_key
}

params = {
    'returnFaceId': 'true',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise'
}

res = requests.post(face_api_url, params=params, headers=headers, data=binary_img)
result = res.json()

rect = result[0]['faceRectangle']

draw = ImageDraw.Draw(img) # imgに描画の準備をする
draw.rectangle([(rect['left'], rect['top']), (rect['left']+rect['width'], rect['top']+rect['height'])], fill=None, outline='green', width=5)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=650x416 at 0x7FC80E4B6D50>

# %%
rect
# Out:
# {'top': 136, 'left': 220, 'width': 189, 'height': 189}

# %%
import requests
from PIL import Image
from PIL import ImageDraw
import io
    
subscription_key = '7ab73decb4dc4191a59fb23b021ebf8b'
assert subscription_key

face_api_url = 'https://20211125sugizaki.cognitiveservices.azure.com/face/v1.0/detect'

img = Image.open('sample3.jpeg')
with io.BytesIO() as output:
    img.save(output, format="JPEG")
    binary_img = output.getvalue() # バイナリデータ取得
    
headers = {
    'Content-Type': 'application/octet-stream',
    'Ocp-Apim-Subscription-Key': subscription_key
}

params = {
    'returnFaceId': 'true',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise'
}

res = requests.post(face_api_url, params=params, headers=headers, data=binary_img)
results = res.json()

for result in results:
    rect = result['faceRectangle']

    draw = ImageDraw.Draw(img) # imgに描画の準備をする
    draw.rectangle([(rect['left'], rect['top']), (rect['left']+rect['width'], rect['top']+rect['height'])], fill=None, outline='green', width=5)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=650x434 at 0x7FC80EC7A250>

# %%
rect
# Out:
# {'top': 136, 'left': 220, 'width': 189, 'height': 189}

# %%
import io

# %%
with io.BytesIO() as output:
    img.save(output, format="JPEG")
    binary_img = output.getvalue() # バイナリデータ取得

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x473 at 0x7FC80D04F590>
